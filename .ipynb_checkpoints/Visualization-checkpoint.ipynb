# %%
import pandas as pd

# %% [markdown]
# # Load data

# %%
df1 = pd.read_csv('data/prepared01.csv')
df2 = pd.read_csv('data/prepared02.csv')

df3_1 = pd.read_csv('data/prepared03-1.csv')
df3_2 = pd.read_csv('data/prepared03-2.csv')
df3_3 = pd.read_csv('data/prepared03-3.csv')
df3_4 = pd.read_csv('data/prepared03-4.csv')

df4 = pd.read_csv('data/prepared04.csv')
df5 = pd.read_csv('data/prepared05.csv')

# %% [markdown]
# ### Combine data

# %%
df = pd.concat([df1, df2, df3_1, df3_2, df3_3, df3_4, df4, df5], ignore_index=True)
len(df)
# Out:
# 1587777

# %%
df1.head()
# Out:
#    Unnamed: 0                 time language               source  group  \
# 0           0  2019-09-27 17:15:51       en   Twitter for iPhone  17 pm
# 1           1  2019-09-27 17:15:51       th  Twitter for Android  17 pm
# 2           2  2019-09-27 17:15:51       es   Twitter for iPhone  17 pm
# 3           3  2019-09-27 17:15:51       en  Twitter for Android  17 pm
# 4           4  2019-09-27 17:15:51       th  Twitter for Android  17 pm
#
#                                              hashtag
# 0                               ['KCON2019THAILAND']
# 1  ['BamBam', 'GOT7', 'Got7Homecoming', 'WelcomeG...
# 2          ['X1', 'X1FlyHighToThailand', 'KCON19TH']
# 3              ['KIMWOOSEOK', 'WelcomeX1toThailand']
# 4    ['GOT7', 'GOT7_Homecoming', 'KCON2019THAILAND']

# %%
df.tail()
# Out:
#          Unnamed: 0                 time language               source  group  \
# 1587772      556770  2019-09-29 17:30:55       th   Twitter for iPhone  17 pm
# 1587773      556771  2019-09-29 17:30:55       th   Twitter for iPhone  17 pm
# 1587774      556772  2019-09-29 17:30:55       en  Twitter for Android  17 pm
# 1587775      556773  2019-09-29 17:30:55       th      Twitter Web App  17 pm
# 1587776      556774  2019-09-29 17:30:55       th   Twitter for iPhone  17 pm
#
#                                                    hashtag
# 1587772                                                 []
# 1587773  ['조승연', 'CHOSEUNGYOUN', 'X1', 'KCON2019THAILAND']
# 1587774  ['KCON2019THAILAND', 'KCON19TH', 'KCON_Concert...
# 1587775  ['남도현', 'NAMDOHYON', 'KCON19TH', 'X1_KCON', 'โ...
# 1587776                                             ['JB']

# %%
df.drop('Unnamed: 0', inplace=True, axis=1)

# %%
df
# Out:
#                         time language               source  group  \
# 0        2019-09-27 17:15:51       en   Twitter for iPhone  17 pm
# 1        2019-09-27 17:15:51       th  Twitter for Android  17 pm
# 2        2019-09-27 17:15:51       es   Twitter for iPhone  17 pm
# 3        2019-09-27 17:15:51       en  Twitter for Android  17 pm
# 4        2019-09-27 17:15:51       th  Twitter for Android  17 pm
# ...                      ...      ...                  ...    ...
# 1587772  2019-09-29 17:30:55       th   Twitter for iPhone  17 pm
# 1587773  2019-09-29 17:30:55       th   Twitter for iPhone  17 pm
# 1587774  2019-09-29 17:30:55       en  Twitter for Android  17 pm
# 1587775  2019-09-29 17:30:55       th      Twitter Web App  17 pm
# 1587776  2019-09-29 17:30:55       th   Twitter for iPhone  17 pm
#
#                                                    hashtag
# 0                                     ['KCON2019THAILAND']
# ...
